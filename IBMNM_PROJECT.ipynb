# %%
import numpy as np
from PIL import Image

def add_noise(image, noise_level=0.1):
    noise = np.random.normal(scale=noise_level, size=image.shape)
    noisy_image = image + noise
    return np.clip(noisy_image, 0, 1)

def generate_diffusion(image_size=(256, 256), num_steps=10000, noise_level=0.1):

    image = np.random.rand(*image_size)
    
 
    for step in range(num_steps):
    
        image = add_noise(image, noise_level)
        

        if step % 100 == 0:
            save_image(image, f'diffusion_step_{step}.png')

def save_image(image, filename):
    image_scaled = (image * 255).astype(np.uint8)
    img = Image.fromarray(image_scaled)
    img.save(filename)

generate_diffusion()

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Function to display an image
def display_image(filename):
    img = Image.open(filename)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# Example usage
display_image('diffusion_step_0.png')

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Function to display an image
def display_image(filename):
    img = Image.open(filename)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# Example usage
display_image('diffusion_step_0.png')
